# %% [markdown]
# <a href="https://colab.research.google.com/github/e-jungs2/DartB-24-2/blob/main/%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Survey date YYYYMM
# * Gender 1 = Male, 2 = Female
# * Level of education 1 = elementary school or less, 2 = middle school, 3 = High school, 4 = Bachelors Degree = 5, 6 = Graduate school
# *Marriage status 1 = Single, 2 = Married, 3 = Bereavement, 4 = Separated, 5 = Divorce, 6 = Other
# * Alcohol drinking 1 = Non-drinker, 2 = formal drinker 3 = regular drinker
# * The total period of drinking 1 = 5 years or less, 2 = 6-10 years, 3 = 11-20 years, 4 = > 21 years
# *Rice wine drinking frequency 0 = None. 1 = once a month, 2 = two or three times a month, 3= once a week, 4 = 2-3 times a week, 5 = 4-6 times a week, 6 = Everyday
# * Amount of Rice wine drink per Drinking () Glass
# * Sake drinking frequency 0 = None. 1 = once a month, 2 = two or three times a month, 3= once a week, 4 = 2-3 times a week, 5 = 4-6 times a week, 6 = Everyday
# *Amount of Sake drinking at once () Glass
# *Wine Drinking Frequency 0 = None. 1 = once a month, 2 = two or three times a month, 3= once a week, 4 = 2-3 times a week, 5 = 4-6 times a week, 6 = Everyday
# * Amount of Wine Drinking at one () Glass
# * Soju Drinking Frequency 0 = None. 1 = once a month, 2 = two or three times a month, 3= once a week, 4 = 2-3 times a week, 5 = 4-6 times a week, 6 = Everyday
# * Amount of soju drinking at once () Glass
# * Beer Drinking Frequency 0 = None. 1 = once a month, 2 = two or three times a month, 3= once a week, 4 = 2-3 times a week, 5 = 4-6 times a week, 6 = Everyday
# * Amount of Beer drinking at once () Bottle
# * Spirits Drinking Frequency 0 = None. 1 = once a month, 2 = two or three times a month, 3= once a week, 4 = 2-3 times a week, 5 = 4-6 times a week, 6 = Everyday
# * Amount of spirits drinking () Shot
# * Smoking status 1 = non-smoker, 2 = formal smoker, 3 = regular smoker
# * Smoking starting age () years old
# * The total duration of Smoking in Total () years
# * Amount of smoking per day () pack
# * Secondhand smoke 1 = no; 2 = yes
# * Frequent high intensity exercise 1 = no; 2 = yes
# * Hypertension history 1 = no; 2 = yes
# * Age when first diagnosed with hypertension ()years old
# * Diagnosed with Diabetes 1 = no; 2 = yes
# * Age when diagnosed with diabetes ()years old
# * Diagnosed with Hyperlipidemia 1 = no; 2 = yes
# * Age when diagnosed with hyperlipidemia ()years old
# * Family history of hypertension (father) 1 = no; 2 = yes
# * Age when father was first diagnosed with hypertentsion ()years old
# * Family history of hypertension (mother) 1 = no; 2 = yes
# * Age when mother was first diagnosed with hypertentsion ()years old
# * Family history of diabetes (father) 1 = no; 2 = yes
# * Age when father was first diagnosed with diabetes ()years old
# * Family history of diabetes (mother) 1 = no; 2 = yes
# * Age when mother was first diagnosed with diabetes ()years old
# * Menarche age ()years old
# * Pregnancy experience 1 = no; 2 = yes
# * Age at first pregnancy ()years old
# * Childbirth 1 = no and 2 = yes
# * Age at first childbirth ()years old
# * Menopause 1 = no; 2 = yes
# * Menopaused age ()years old
# * Height () cm
# * Weight () kg
# * The average waist circumference () cm
# * The average hip circumference () cm
# * Average heart rate () Times / min.
# * Systolic blood pressure () mmHg
# * Diastolic blood pressure () mmHg
# * HbA1C ()%
# * Fasting Glucose () mg / dL
# * Creatinine () mg / dL
# * AST () IU / L
# * ALT () IU / L
# * Total Cholesterol () mg / dL
# * HDL-Cholesterol () mg / dL
# * Triglyceride () mg / dL
# * Fasting Insulin () µIU / mL
#
# [**Code** 66666: Not surveyed; 77777: Not applicable; 99999: Unknown/Not answered/Not measured]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/drive/MyDrive/다트비/토이프로젝트(1)-한국인건강데이터/원시데이터/follow_01_data.csv')
display(df1)
# Out:
#             T00_ID T00_DATA_CLASS  T01_EDATE  T00_SEX  T01_AGE  T01_EDU  \
# 0    K_FOLLOW_0001            F05     200412        1       56        1
# 1    K_FOLLOW_0002            F19     200401        1       40        3
# 2    K_FOLLOW_0003            F05     200309        1       52        2
# 3    K_FOLLOW_0004            F05     200504        2       60        2
# 4    K_FOLLOW_0005            F19     200402        1       49        3
# ..             ...            ...        ...      ...      ...      ...
# 995  K_FOLLOW_0996            F05     200507        1       64        1
# 996  K_FOLLOW_0997            F18     200411        1       63        3
# 997  K_FOLLOW_0998            F19     200401        1       41        5
# 998  K_FOLLOW_0999            F11     200501        2       69        1
# 999  K_FOLLOW_1000            F19     200311        2       45        2
#
#      T01_MARRY  T01_DRINK  T01_DRDU  T01_TAKFQ  ...  T01_DBP  T01_HBA1C  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/다트비/토이프로젝트(1)-한국인건강데이터/원시데이터/follow_02_data.csv')
display(df2)
# Out:
#             T00_ID T00_DATA_CLASS  T02_EDATE  T02_AGE  T02_MARRY  T02_DRINK  \
# 0    K_FOLLOW_0001            F05     200609       58      66666          2
# 1    K_FOLLOW_0002            F19     200510       41          2          3
# 2    K_FOLLOW_0003            F05     200505       54      66666          3
# 3    K_FOLLOW_0004            F05     200704       62      66666          1
# 4    K_FOLLOW_0005            F19     200601       51          2          3
# ..             ...            ...        ...      ...        ...        ...
# 980  K_FOLLOW_0996            F05     200705       66      66666          1
# 981  K_FOLLOW_0997            F18     200606       65          2          3
# 982  K_FOLLOW_0998            F19     200510       43          2          3
# 983  K_FOLLOW_0999            F11     200608       71          2          2
# 984  K_FOLLOW_1000            F19     200507       47          2          1
#
# ...

# %%
df3 = pd.read_csv('/content/drive/MyDrive/다트비/토이프로젝트(1)-한국인건강데이터/원시데이터/follow_03_data.csv')
display(df3)
# Out:
#             T00_ID T00_DATA_CLASS  T03_EDATE  T03_AGE  T03_MARRY  T03_DRINK  \
# 0    K_FOLLOW_0001            F05     200909       61          2          2
# 1    K_FOLLOW_0002            F19     200810       44          2          3
# 2    K_FOLLOW_0003            F05     200806       57          2          3
# 3    K_FOLLOW_0004            F05     201005       65          2          1
# 4    K_FOLLOW_0005            F19     200901       54          2          3
# ..             ...            ...        ...      ...        ...        ...
# 948  K_FOLLOW_0996            F05     201006       69          2          1
# 949  K_FOLLOW_0997            F18     200909       68          2          3
# 950  K_FOLLOW_0998            F19     200809       46          2          3
# 951  K_FOLLOW_0999            F11     201003       74          2          1
# 952  K_FOLLOW_1000            F19     200808       50          2          1
#
# ...

# %%
df4 = pd.read_csv('/content/drive/MyDrive/다트비/토이프로젝트(1)-한국인건강데이터/원시데이터/follow_04_data.csv')
display(df4)
# Out:
#             T00_ID T00_DATA_CLASS  T04_EDATE  T04_AGE  T04_MARRY  T04_DRINK  \
# 0    K_FOLLOW_0001            F05     201208       64          2          2
# 1    K_FOLLOW_0002            F19     201110       47          2          3
# 2    K_FOLLOW_0003            F05     201106       60          2          3
# 3    K_FOLLOW_0004            F05     201304       68          3          1
# 4    K_FOLLOW_0005            F19     201111       57          2          3
# ..             ...            ...        ...      ...        ...        ...
# 894  K_FOLLOW_0996            F05     201304       72          2          1
# 895  K_FOLLOW_0997            F18     201311       72          2          3
# 896  K_FOLLOW_0998            F19     201111       49          2          3
# 897  K_FOLLOW_0999            F11     201310       78          2          1
# 898  K_FOLLOW_1000            F19     201107       53          2          1
#
# ...

# %%
df5 = pd.read_csv('/content/drive/MyDrive/다트비/토이프로젝트(1)-한국인건강데이터/원시데이터/follow_05_data.csv')
display(df5)
# Out:
#             T00_ID T00_DATA_CLASS  T05_EDATE  T05_AGE  T05_MARRY  T05_DRINK  \
# 0    K_FOLLOW_0001            F05     201510       67          2          1
# 1    K_FOLLOW_0002            F19     201410       50          2          3
# 2    K_FOLLOW_0003            F05     201406       63          2          3
# 3    K_FOLLOW_0005            F19     201412       60          2          3
# 4    K_FOLLOW_0007            F05     201509       59          2          1
# ..             ...            ...        ...      ...        ...        ...
# 693  K_FOLLOW_0993            F05     201505       74          3          2
# 694  K_FOLLOW_0995            F19     201412       55          2          3
# 695  K_FOLLOW_0996            F05     201605       75          2          1
# 696  K_FOLLOW_0998            F19     201410       52          2          3
# 697  K_FOLLOW_1000            F19     201410       56          2          1
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 64 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   T00_ID          1000 non-null   object
#  1   T00_DATA_CLASS  1000 non-null   object
#  2   T01_EDATE       1000 non-null   int64
#  3   T00_SEX         1000 non-null   int64
#  4   T01_AGE         1000 non-null   int64
#  5   T01_EDU         1000 non-null   int64
#  6   T01_MARRY       1000 non-null   int64
#  7   T01_DRINK       1000 non-null   int64
#  8   T01_DRDU        1000 non-null   int64
#  9   T01_TAKFQ       1000 non-null   int64
#  10  T01_TAKAM       1000 non-null   float64
#  11  T01_RICEFQ      1000 non-null   int64
#  12  T01_RICEAM      1000 non-null   float64
#  13  T01_WINEFQ      1000 non-null   int64
#  14  T01_WINEAM      1000 non-null   float64
#  15  T01_SOJUFQ      1000 non-null   int64
#  16  T01_SOJUAM      1000 non-null   float64
# ...

# %%
df1.describe()
# Out:
#            T01_EDATE      T00_SEX      T01_AGE       T01_EDU     T01_MARRY  \
# count    1000.000000  1000.000000  1000.000000   1000.000000   1000.000000
# mean   200403.853000     1.558000    54.334000    702.283000    402.106000
# std        68.758644     0.496873     9.023517   8341.161821   6314.854935
# min    200301.000000     1.000000    40.000000      1.000000      1.000000
# 25%    200312.000000     1.000000    46.000000      1.000000      2.000000
# 50%    200408.000000     2.000000    54.000000      2.000000      2.000000
# 75%    200412.000000     2.000000    62.000000      3.000000      2.000000
# max    200512.000000     2.000000    74.000000  99999.000000  99999.000000
#
#           T01_DRINK      T01_DRDU     T01_TAKFQ     T01_TAKAM    T01_RICEFQ  \
# count   1000.000000   1000.000000   1000.000000   1000.000000   1000.000000
# mean     701.955000  41478.984000   1300.120000  73788.281100   1200.032000
# ...

# %%
smoke_value = df1['T01_SMOKE'].value_counts()
smoke_value
# Out:
# T01_SMOKE
# 1        628
# 3        192
# 2        171
# 99999      9
# Name: count, dtype: int64

# %%
print(df1.isnull().sum())
# Out:
# T00_ID            0
# T00_DATA_CLASS    0
# T01_EDATE         0
# T00_SEX           0
# T01_AGE           0
#                  ..
# T01_ALT           0
# T01_TCHL          0
# T01_HDL           0
# T01_TG            0
# T01_INS0          0
# Length: 64, dtype: int64

# %% [markdown]
# 결측치 안 잡힘..

# %%
df1.replace([66666, 77777, 99999, 66666.0, 77777.0, 99999.0], np.nan, inplace=True)

# %%
display(df1.isnull().sum())
# Out:
# T00_ID              0
# T00_DATA_CLASS      0
# T01_EDATE           0
# T00_SEX             0
# T01_AGE             0
#                  ...
# T01_ALT             0
# T01_TCHL            0
# T01_HDL             0
# T01_TG              1
# T01_INS0          196
# Length: 64, dtype: int64
